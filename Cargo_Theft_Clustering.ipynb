# %% [markdown]
# # Cargo Theft Data Clustering
# ## Import and Trim a Little More

# %%
# Start with magic
# %matplotlib inline

# Import the necessary dependencies.
import pandas as pd
import numpy as np
import matplotlib as plt
from sklearn.preprocessing import StandardScaler, MinMaxScaler
from sklearn.decomposition import PCA
from sklearn.cluster import KMeans

# %%
# Get the Crime Report data.
df = pd.read_csv("Datasets/CrimeReport.csv")
df.head()
# Out:
#    data_year pub_agency_name agency_type_name state_name       division_name  \
# 0       2021        Angelina           County      Texas  West South Central
# 1       2021       Jefferson           County    Alabama  East South Central
# 2       2021       Jefferson           County    Alabama  East South Central
# 3       2021       Jefferson           County    Alabama  East South Central
# 4       2021       Jefferson           County    Alabama  East South Central
#
#   county_name region_name population_group_code  \
# 0    ANGELINA       South                    8B
# 1   JEFFERSON       South                    9A
# 2   JEFFERSON       South                    9A
# 3   JEFFERSON       South                    9A
# 4   JEFFERSON       South                    9A
#
#                       population_group_desc offense_code  ... location_code  \
# 0  Non-MSA counties from 25,000 thru 99,999          26B  ...            25
# 1              MSA counties 100,000 or over          23H  ...            20
# 2              MSA counties 100,000 or over          23H  ...            20
# 3              MSA counties 100,000 or over          23H  ...            20
# 4              MSA counties 100,000 or over          23F  ...            20
#
#     location_name weapon_code  weapon_name prop_desc_code      prop_desc_name  \
# 0   Other/Unknown          95      Unknown             20               Money
# 1  Residence/Home          95      Unknown             77               Other
# 2  Residence/Home          95      Unknown             65  Identity Documents
# 3  Residence/Home          95      Unknown             13            Firearms
# 4  Residence/Home          95      Unknown             77               Other
#
#   stolen_value  recovered_value recovered_flag date_recovered
# 0        375.0                0          False            NaN
# 1          1.0                0          False            NaN
# 2          0.0                0          False            NaN
# 3        320.0                0          False            NaN
# 4          1.0                0          False            NaN
#
# [5 rows x 27 columns]

# %%
# The dates, the agency, the offender, and the weapon will not be factored into this.
# The state is favored as the middle between the county and the region/division.
# Thus, these shall all be dropped.
dropped = ["data_year", "pub_agency_name", "agency_type_name",
           "division_name", "county_name", "region_name",
           "offender_race", "offender_ethnicity", "offender_age",
           "offender_sex", "weapon_code", "weapon_name", "date_recovered"]
df0 = df.drop(columns = dropped, axis = 1)
df0.head()
# Out:
#   state_name population_group_code                     population_group_desc  \
# 0      Texas                    8B  Non-MSA counties from 25,000 thru 99,999
# 1    Alabama                    9A              MSA counties 100,000 or over
# 2    Alabama                    9A              MSA counties 100,000 or over
# 3    Alabama                    9A              MSA counties 100,000 or over
# 4    Alabama                    9A              MSA counties 100,000 or over
#
#   offense_code                                offense_name victim_type_code  \
# 0          26B  Credit Card/Automated Teller Machine Fraud                I
# 1          23H                           All Other Larceny                I
# 2          23H                           All Other Larceny                I
# 3          23H                           All Other Larceny                I
# 4          23F                    Theft From Motor Vehicle                I
#
#   victim_type_name  location_code   location_name  prop_desc_code  \
# 0       Individual             25   Other/Unknown              20
# 1       Individual             20  Residence/Home              77
# 2       Individual             20  Residence/Home              65
# 3       Individual             20  Residence/Home              13
# 4       Individual             20  Residence/Home              77
#
#        prop_desc_name  stolen_value  recovered_value  recovered_flag
# 0               Money         375.0                0           False
# 1               Other           1.0                0           False
# 2  Identity Documents           0.0                0           False
# 3            Firearms         320.0                0           False
# 4               Other           1.0                0           False

# %% [markdown]
# ## I. First Selection - The Stolen Values of Objects as a Whole

# %%
# Set up the DataFrame.
stolen_df = df0[["state_name", "population_group_code", "offense_code", "victim_type_code",
                 "location_code", "prop_desc_code", "stolen_value"]]
stolen_df.head()
# Out:
#   state_name population_group_code offense_code victim_type_code  \
# 0      Texas                    8B          26B                I
# 1    Alabama                    9A          23H                I
# 2    Alabama                    9A          23H                I
# 3    Alabama                    9A          23H                I
# 4    Alabama                    9A          23F                I
#
#    location_code  prop_desc_code  stolen_value
# 0             25              20         375.0
# 1             20              77           1.0
# 2             20              65           0.0
# 3             20              13         320.0
# 4             20              77           1.0

# %%
# Null values should have been dealt with, but are there any duplicates again?
stolen_df.duplicated().sum()
# Out:
# 24697

# %%
# Deal with the duplicates.
stolen_df.drop_duplicates()
# Out:
#             state_name population_group_code offense_code victim_type_code  \
# 0                Texas                    8B          26B                I
# 1              Alabama                    9A          23H                I
# 2              Alabama                    9A          23H                I
# 3              Alabama                    9A          23H                I
# 4              Alabama                    9A          23F                I
# ...                ...                   ...          ...              ...
# 122951         Florida                    9A          23F                B
# 122952         Florida                    9A          23F                B
# 122953  South Carolina                    9A          240                B
# 122954       Tennessee                    1B          23F                B
# 122955  South Carolina                    9A          240                B
#
#         location_code  prop_desc_code  stolen_value
# 0                  25              20         375.0
# 1                  20              77           1.0
# 2                  20              65           0.0
# 3                  20              13         320.0
# 4                  20              77           1.0
# ...               ...             ...           ...
# 122951             25              37       10000.0
# 122952             25              36          35.0
# 122953             18              78       20000.0
# 122954              7               2          32.0
# 122955             18              77       27000.0
#
# [98259 rows x 7 columns]

# %% [markdown]
# ## II. Second Selection - Look at the Recovered Subset

# %%
# Set up the DataFrame.
recov_df = df0.loc[df0.recovered_flag == True][["state_name", "population_group_code", "offense_code",
                                                "victim_type_code", "location_code", "prop_desc_code",
                                                "stolen_value", "recovered_value"]]
recov_df.head()
# Out:
#        state_name population_group_code offense_code victim_type_code  \
# 16        Alabama                    9B          23H                I
# 42  West Virginia                    9A          23H                I
# 46        Alabama                     2          240                I
# 49        Alabama                     2          240                I
# 66        Alabama                     2          240                I
#
#     location_code  prop_desc_code  stolen_value  recovered_value
# 16             20               9           0.0                0
# 42             25              77        5000.0             5000
# 46             20               3       12000.0            12000
# 49             20               3       11000.0            11000
# 66             18               3       20000.0            20000

# %%
# Find the recovery percentage.
recov_df["recovery_rate"] = np.where(recov_df.stolen_value > 0,
                                     recov_df.recovered_value / recov_df.stolen_value, 0)
recov_df.head()
# Out:
#        state_name population_group_code offense_code victim_type_code  \
# 16        Alabama                    9B          23H                I
# 42  West Virginia                    9A          23H                I
# 46        Alabama                     2          240                I
# 49        Alabama                     2          240                I
# 66        Alabama                     2          240                I
#
#     location_code  prop_desc_code  stolen_value  recovered_value  \
# 16             20               9           0.0                0
# 42             25              77        5000.0             5000
# 46             20               3       12000.0            12000
# 49             20               3       11000.0            11000
# 66             18               3       20000.0            20000
#
#     recovery_rate
# 16            0.0
# 42            1.0
# 46            1.0
# 49            1.0
# 66            1.0

# %%
# Null values should have been dealt with, but are there any duplicates again?
recov_df.duplicated().sum()
# Out:
# 4239

# %%
# Deal with the duplicates.
recov_df.drop_duplicates()
# Out:
#             state_name population_group_code offense_code victim_type_code  \
# 16             Alabama                    9B          23H                I
# 42       West Virginia                    9A          23H                I
# 46             Alabama                     2          240                I
# 49             Alabama                     2          240                I
# 66             Alabama                     2          240                I
# ...                ...                   ...          ...              ...
# 122938  South Carolina                     7          23F                B
# 122944         Florida                    9A          240                B
# 122951         Florida                    9A          23F                B
# 122953  South Carolina                    9A          240                B
# 122955  South Carolina                    9A          240                B
#
#         location_code  prop_desc_code  stolen_value  recovered_value  \
# 16                 20               9           0.0                0
# 42                 25              77        5000.0             5000
# 46                 20               3       12000.0            12000
# 49                 20               3       11000.0            11000
# 66                 18               3       20000.0            20000
# ...               ...             ...           ...              ...
# 122938             18               7        3000.0             3000
# 122944              0              37       10000.0            10000
# 122951             25              37       10000.0            10000
# 122953             18              78       20000.0            20000
# 122955             18              77       27000.0            27000
#
#         recovery_rate
# 16                0.0
# 42                1.0
# 46                1.0
# 49                1.0
# 66                1.0
# ...               ...
# 122938            1.0
# 122944            1.0
# 122951            1.0
# 122953            1.0
# 122955            1.0
#
# [13042 rows x 9 columns]
