# %% [markdown]
# # Cargo Theft Data Pre-Processing
#
# ## Import and Check Out the Data

# %%
# Matplotlib inline magic
# %matplotlib inline

# Import the necessary dependencies
import pandas as pd
import numpy as np
import matplotlib as plt
import json

# %%
# Read the CSV file into a DataFrame.
df = pd.read_csv("Resources/CT_2013_2021.csv")
df.head(15)
# Out:
#     data_year        ori pub_agency_name pub_agency_unit agency_type_name  \
# 0        2021  TX0030000        Angelina             NaN           County
# 1        2021  AL0010000       Jefferson             NaN           County
# 2        2021  AL0010000       Jefferson             NaN           County
# 3        2021  AL0010000       Jefferson             NaN           County
# 4        2021  AL0010000       Jefferson             NaN           County
# 5        2021  AL0010000       Jefferson             NaN           County
# 6        2021  AL0010000       Jefferson             NaN           County
# 7        2021  AL0020100          Mobile             NaN             City
# 8        2021  AL0020100          Mobile             NaN             City
# 9        2021  AL0020100          Mobile             NaN             City
# 10       2021  AL0020100          Mobile             NaN             City
# 11       2021  AL0020100          Mobile             NaN             City
# 12       2021  AL0020100          Mobile             NaN             City
# 13       2021  AL0020100          Mobile             NaN             City
# 14       2021  AL0020100          Mobile             NaN             City
#
#    state_abbr state_name       division_name county_name region_name  ...  \
# 0          TX      Texas  West South Central    ANGELINA       South  ...
# 1          AL    Alabama  East South Central   JEFFERSON       South  ...
# 2          AL    Alabama  East South Central   JEFFERSON       South  ...
# 3          AL    Alabama  East South Central   JEFFERSON       South  ...
# 4          AL    Alabama  East South Central   JEFFERSON       South  ...
# 5          AL    Alabama  East South Central   JEFFERSON       South  ...
# 6          AL    Alabama  East South Central   JEFFERSON       South  ...
# 7          AL    Alabama  East South Central      MOBILE       South  ...
# 8          AL    Alabama  East South Central      MOBILE       South  ...
# 9          AL    Alabama  East South Central      MOBILE       South  ...
# 10         AL    Alabama  East South Central      MOBILE       South  ...
# 11         AL    Alabama  East South Central      MOBILE       South  ...
# 12         AL    Alabama  East South Central      MOBILE       South  ...
# 13         AL    Alabama  East South Central      MOBILE       South  ...
# 14         AL    Alabama  East South Central      MOBILE       South  ...
#
#    weapon_code weapon_name prop_desc_code data_year.1 prop_desc_code.1  \
# 0          NaN         NaN             20        2021               20
# 1          NaN         NaN             77        2021               77
# 2          NaN         NaN             65        2021               65
# 3          NaN         NaN             13        2021               13
# 4          NaN         NaN             77        2021               77
# 5          NaN         NaN             65        2021               65
# 6          NaN         NaN             13        2021               13
# 7          NaN         NaN             26        2021               26
# 8          NaN         NaN             17        2021               17
# 9          NaN         NaN             38        2021               38
# 10         NaN         NaN             36        2021               36
# 11         NaN         NaN             77        2021               77
# 12         NaN         NaN             68        2021               68
# 13         NaN         NaN              9        2021                9
# 14         NaN         NaN             38        2021               38
#
#                   prop_desc_name  stolen_value recovered_value recovered_flag  \
# 0                          Money         375.0               0          False
# 1                          Other           1.0               0          False
# 2             Identity Documents           0.0               0          False
# 3                       Firearms         320.0               0          False
# 4                          Other           1.0               0          False
# 5             Identity Documents           0.0               0          False
# 6                       Firearms         320.0               0          False
# 7                 Radio/ TV/ VCR         900.0               0          False
# 8       Jewelry/ Precious Metals         400.0               0          False
# 9                  Vehicle Parts        9900.0               0          False
# 10                         Tools        3984.0               0          False
# 11                         Other         600.0               0          False
# 12  Lawn/ Yard/ Garden Equipment         600.0               0          False
# 13           Credit/ Debit cards           0.0               0          False
# 14                 Vehicle Parts        2400.0               0          False
#
#    date_recovered
# 0             NaN
# 1             NaN
# 2             NaN
# 3             NaN
# 4             NaN
# 5             NaN
# 6             NaN
# 7             NaN
# 8             NaN
# 9             NaN
# 10            NaN
# 11            NaN
# 12            NaN
# 13            NaN
# 14            NaN
#
# [15 rows x 32 columns]
